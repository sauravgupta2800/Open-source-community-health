# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('contributor_records.csv')
df.describe()
# Out:
#               Mean       Median        Range           q1           q2
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000  \
# mean     20.259335     4.742000   549.860667     2.401333     4.742000
# std      56.220164    21.632431  1254.555120    10.879239    21.632431
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%      12.664583     1.000000   248.250000     1.000000     1.000000
# max     461.800000   215.000000  8334.000000   104.000000   215.000000
#
#                 q3          Std
# count  1500.000000  1500.000000
# mean     11.900000    68.393763
# std      50.365542   150.355079
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       3.000000    44.566251
# max     449.000000   893.699969

# %%
filtered_df = df[df['Mean'] != 0]
print(filtered_df.describe())
filtered_df = df.loc[:, ['ecosystem', 'Mean', 'Median', 'Range', 'q1', 'q2', 'q3', 'Std']]
# Out:
#              Mean      Median        Range          q1          q2
# count  613.000000  613.000000   613.000000  613.000000  613.000000  \
# mean    49.574230   11.603589  1345.499184    5.876020   11.603589
# std     79.284474   32.656578  1668.162772   16.414891   32.656578
# min      1.000000    1.000000     0.000000    1.000000    1.000000
# 25%      8.070000    1.000000   123.000000    1.000000    1.000000
# 50%     18.619048    2.000000   490.000000    1.000000    2.000000
# 75%     49.910000    4.000000  2167.000000    2.000000    4.000000
# max    461.800000  215.000000  8334.000000  104.000000  215.000000
#
#                q3         Std
# count  613.000000  613.000000
# mean    29.119086  167.358312
# std     75.571183  196.931241
# min      1.000000    0.000000
# 25%      2.000000   24.635115
# 50%      3.000000   74.350841
# 75%     13.000000  262.705434
# max    449.000000  893.699969

# %%
# Group the data by 'ecosystem' and calculate the average for each metric
averages = filtered_df.groupby('ecosystem').mean()
averages
# Out:
#                 Mean  Median    Range     q1     q2      q3        Std
# ecosystem
# npm        13.320838   2.894  403.762  1.542  2.894   6.542  48.598825
# pypi       20.723001   5.232  447.422  2.472  5.232  14.270  60.565339
# rubygems   26.734167   6.100  798.398  3.190  6.100  14.888  96.017125

# %%
metrics = ['Mean', 'Median', 'Range', 'q1', 'q2', 'q3', 'Std']

# Create bar plots for each metric
for metric in metrics:
    plt.figure(figsize=(3, 2))
    plt.bar(averages.index, averages[metric], color=['red', 'blue', 'green'])
    plt.xlabel('Ecosystem')
    plt.ylabel(metric)
    plt.title(f'Average {metric} Comparison by Ecosystem')
    plt.show()
