# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('contributor_records.csv')
df.describe()
# Out:
#               Mean       Median        Range           q1           q2
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  \
# mean     30.454014     5.728500   851.471500     2.753000     5.728500
# std      86.855105    36.835407  1975.906436    14.860667    36.835407
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max     915.560000   567.000000  9258.000000   193.000000   567.000000
#
#                 q3          Std
# count  2000.000000  2000.000000
# mean     14.422000   109.893012
# std      81.985662   265.014605
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max    1193.000000  1490.089646

# %%
filtered_df = df[df['Mean'] != 0]
print(filtered_df.describe())
filtered_df = df.loc[:, ['ecosystem', 'Mean', 'Median', 'Range', 'q1', 'q2', 'q3', 'Std']]
# Out:
#              Mean      Median        Range          q1          q2
# count  458.000000  458.000000   458.000000  458.000000  458.000000  \
# mean   132.986962   25.015284  3718.216157   12.021834   25.015284
# std    139.041695   73.834769  2528.872894   29.228736   73.834769
# min      6.720930    1.000000   145.000000    1.000000    1.000000
# 25%     50.230000    2.000000  1980.000000    1.000000    2.000000
# 50%     90.670000    4.000000  3204.000000    2.000000    4.000000
# 75%    183.510000   10.000000  5034.000000    7.000000   10.000000
# max    915.560000  567.000000  9258.000000  193.000000  567.000000
#
#                 q3          Std
# count   458.000000   458.000000
# mean     62.978166   479.882149
# std     162.286869   359.542647
# min       1.000000    24.137518
# 25%       4.000000   272.848988
# 50%      12.500000   326.258789
# 75%      35.000000   700.128892
# max    1193.000000  1490.089646

# %%
# Group the data by 'ecosystem' and calculate the average for each metric
averages = filtered_df.groupby('ecosystem').mean()
averages
# Out:
#                 Mean  Median     Range     q1      q2      q3         Std
# ecosystem
# maven      69.853520  11.464  1811.376  4.896  11.464  28.092  253.205762
# npm        10.052448   1.772   352.158  1.044   1.772   4.718   39.298189
# pypi       15.029783   4.042   286.540  2.206   4.042  11.118   38.419090
# rubygems   26.880307   5.636   955.812  2.866   5.636  13.760  108.649007

# %%
metrics = ['Mean', 'Median', 'Range', 'q1', 'q2', 'q3', 'Std']

# Create bar plots for each metric
for metric in metrics:
    plt.figure(figsize=(3, 2))
    plt.bar(averages.index, averages[metric], color=['brown', 'red', 'blue', 'green'])
    plt.xlabel('Ecosystem')
    plt.ylabel(metric)
    plt.title(f'Average {metric} Comparison by Ecosystem')
    plt.show()
